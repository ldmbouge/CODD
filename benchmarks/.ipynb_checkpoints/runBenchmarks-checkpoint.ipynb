# %%
# Auxiliary functions
def readLines(filepath):
    with open(filepath, "r", encoding="utf-8") as f:
        return [line.strip() for line in f]

# %%
# Data
benchmarkSet = [
    "AFG.txt",
    "Dumas.txt",
    "GendreauDumasExtended.txt",
    "Langevin.txt",
    "OhlmannThomas.txt",
    "Solnon25_feasible.txt",
    "Solnon25_infeasible.txt",
    "SolomonPesant.txt",
    "SolomonPotvinBengio.txt"
]
timeout = 20 * 60 
exe = "../cmake-build-release-ding/tsptw3gpu"
resultsDir  = "./results"

# %%
import subprocess
from datetime import datetime

# Run
useGpu = True
for benchmark in benchmarkSet:
    logfile = resultsDir + "/" + benchmark.removesuffix(".txt") + "_" + ("g" if useGpu else "c") + "_" + str(timeout) + "_" + datetime.now().strftime("%Y%m%d%H%M") + ".txt"
    instances = readLines(benchmark)
    with open(logfile, "w") as f:
        for instance in instances:
            cmd = [exe, 
                   "-w", 2,
                   "-s", "RONQ",
                   "-t", timeout,
                   "-g", (0 if useGpu else 32 * 1024 * 1024),
                   "-i", instance
                  ]
            cmdStr = " ".join(str(c) for c in cmd);
            print(cmdStr)
            f.write(cmdStr + "\n")
            #subprocess.run(cmd, stdout=f, stderr=f)
            f.write("\n")
            f.flush()
# Out:
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg132.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg020a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg152.3.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg193.2.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg040a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg019b.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.6.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg035a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg027a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.2.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg055a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg016a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg067a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.5.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg017a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg201a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.3.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg193.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg010a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.7.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg233.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg049a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg152.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg019d.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.8.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg016b.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg034a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.4.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg050b.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg172a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg125a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg132.2.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg017.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg031a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg042a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg019a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg086a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg050c.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg233.2.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg035a.2.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg033a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg019c.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg092a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg048a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg050a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.9.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg041a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg017.2.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg038a.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/AFG/rbg021.tw
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w60.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w60.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w80.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w80.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w80.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w60.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w100.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w60.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w60.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w60.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w60.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w60.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w100.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w100.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w80.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w60.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w80.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w100.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w80.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w100.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w80.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w100.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w60.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w60.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w60.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w60.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w60.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w80.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w60.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w100.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w60.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w60.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w80.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w80.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w60.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w100.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w100.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w60.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w80.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w80.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w80.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w60.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w60.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w60.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w60.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w60.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w80.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w60.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w60.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w100.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w100.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w80.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w100.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w20.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w100.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w20.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w80.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w40.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w60.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w60.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w80.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n100w60.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w100.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n150w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w80.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n20w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w40.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w80.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w100.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w80.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w40.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n200w20.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w60.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w40.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n60w20.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n80w40.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/Dumas/n40w20.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w180.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w180.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w140.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w100.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w160.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w140.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w120.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w160.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w100.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w160.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w100.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w200.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w200.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w140.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w140.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w180.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w140.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w120.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w180.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w120.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w80.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w140.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w100.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w180.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w100.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w180.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w200.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w180.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w120.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w120.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w120.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w80.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w200.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w140.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w160.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w200.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w140.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w140.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w140.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w120.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w160.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w120.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w180.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w160.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w140.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w140.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w180.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w80.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w200.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w200.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w120.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w120.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w160.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w200.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w140.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w160.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w180.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w160.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w100.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w180.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w140.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w140.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w140.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w120.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w140.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w180.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w200.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n60w200.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w160.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n80w140.003.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w140.002.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w200.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n20w200.001.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n40w160.005.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100w160.004.txt
# ../cmake-build-release-ding/tsptw3gpu -w 2 -s RONQ -t 1200 -g 0 -i ../data/tsptw/GendreauDumasExtended/n100